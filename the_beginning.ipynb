# %%
class Account:

    def __init__(self):
        pass
    #account_id = must contain '123456789'
    #balance
    #interest
    def get_account(self):
        pass #get method

    def set_account(self):
        pass

    account = property(get_account, set_account)




class Checking(Account):
    pass
    def __init__(self):
        super().__init__()
    # interest is 0%
    def get_checking(self):
        pass
    def set_checking(self):
        pass

    checking = property(get_checking, set_checking)


class Savings(Account):
    pass
    super().__init__()
    # interest is 1%
    def get_savings(self):
        pass
    def set_savings(self):
        pass

    savings = property(get_savings, set_savings)    


class Credit(Account):
    pass
    super.__init__()
    # credit limit as max value
    # overload __str__ possibly using super() to include credit limit
    def get_credit(self):
        pass
    def set_credit(self):
        pass

    credit = property(get_credit, set_credit)      


class Customer(Account):
    pass
    # username
    # checking
    # savings
    # credit

# %%
def view_customers():

    print('Enter your customer id:', flush=True)
    id = input() # You can ask for additional input within a function.
    print(f'{id} has been selected', flush=True)
    print(flush=True) # prints a blank line for better formatting


def deposit():
    global deposit_amount

    # need to select customer, select savings or checking
    print('How much would you like to deposit?', flush=True)

    deposit_input = input()

    try:
        deposit_amount = float(deposit_input)
        
    except ValueError:
        print('This is not a number, try again', flush=True)
        deposit()

    print(f'Confirm the following deposit amount with Y or N: {deposit_amount}.', flush=True)
    confirmation = input()
    print(flush=True)
    
    if deposit_amount > 0:
        if confirmation.upper() == 'Y':
            print(f'Your deposit of ${deposit_amount}0 has been made')
            print(flush=True) # prints a blank line for better formatting
        elif confirmation.upper() == 'N':
            print('Invalid confirmation. Deposit not made. Returning to main menu.', flush=True)
            interface()    
        else:
            print('Invalid confirmation. Deposit not made', flush=True)
    else:
        print('Invalid deposit amount, must be a positive number', flush=True)
        

def withdraw():
    global withdraw_amount
     # need to select customer, select savings or checking
    print('How much would you like to withdraw? (include - before the integer)', flush=True)

    withdraw_input = input()

    try:
        withdraw_amount = float(withdraw_input)
        
    except ValueError:
        print('This is not a number, try again', flush=True)
        deposit()

    print(f'Confirm the following withdrawl amount with Y or N: {withdraw_amount}', flush=True)
    confirmation = input()
    print(flush=True)
    
    if withdraw_amount < 0:
        if confirmation.upper() == 'Y':
            print(f'Your withdrawl of ${withdraw_amount} has been made')
            print(flush=True) # prints a blank line for better formatting
        elif confirmation.upper() == 'N':
            print('Invalid confirmation. Withdraw not made. Returning to main menu.', flush=True)
            interface()    
        else:
            print('Invalid confirmation. Withdraw not made', flush=True)
    else:
        print('Invalid withdrawl amount, must be a negative number', flush=True)


def cc_charge():
    pass


def cc_payment():
    pass


def exit():
    pass





def interface():

    choice = ''
    while choice != '6':

        # Print the interface options
        print('Select an option:', flush=True)
        print("1: View Customers", flush=True)
        print("2: Deposit", flush=True)
        print("3: Withdraw", flush=True)
        print("4: Credit Card Charge", flush=True)
        print("5: Credit Card Payment", flush=True)
        print("6: Exit.", flush=True)
        print(flush=True) # prints a blank line for better formatting

        # Collect user input
        choice = input()
    
        if choice == '1':
            view_customers()
        elif choice == '2':
            deposit()
        elif choice == '3':
            withdraw()
        elif choice == '4':
            cc_charge()
        elif choice == '5':
            cc_payment()
        elif choice == '6':
            print("Shutting down...", flush=True)
            exit() #?????
        else:
            print("Please select an actual option.", flush=True)

# %%
interface()
